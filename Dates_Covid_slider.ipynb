# %%
import pandas as pd
import json
import requests 
import datetime as dt
import numpy as np
import scipy.stats as st
from scipy import stats

# %%
covid_data = pd.read_json("./Data/covid_data.json")
covid_data
# Out:
#            date state  fips  positive  probableCases   negative  \
# 0      20210307    AK     2   56886.0            NaN        NaN
# 1      20210307    AL     1  499819.0       107742.0  1931711.0
# 2      20210307    AR     5  324818.0        69092.0  2480716.0
# 3      20210307    AS    60       0.0            NaN     2140.0
# 4      20210307    AZ     4  826454.0        56519.0  3073010.0
# ...         ...   ...   ...       ...            ...        ...
# 20775  20200117    WA    53       0.0            NaN        NaN
# 20776  20200116    WA    53       0.0            NaN        NaN
# 20777  20200115    WA    53       0.0            NaN        NaN
# 20778  20200114    WA    53       0.0            NaN        NaN
# 20779  20200113    WA    53       NaN            NaN        NaN
#
#        hospitalizedCumulative  recovered    death  positiveCasesViral  \
# 0                      1293.0        NaN    305.0                 NaN
# ...

# %%
covid_data20=covid_data.copy()
covid_data20.dtypes
# Out:
# date                        int64
# state                      object
# fips                        int64
# positive                  float64
# probableCases             float64
# negative                  float64
# hospitalizedCumulative    float64
# recovered                 float64
# death                     float64
# positiveCasesViral        float64
# deathConfirmed            float64
# State                      object
# dtype: object

# %%
covid_data20['date'] = pd.to_datetime(covid_data20['date'],format='%Y%m%d')
covid_data20
# Out:
#             date state  fips  positive  probableCases   negative  \
# 0     2021-03-07    AK     2   56886.0            NaN        NaN
# 1     2021-03-07    AL     1  499819.0       107742.0  1931711.0
# 2     2021-03-07    AR     5  324818.0        69092.0  2480716.0
# 3     2021-03-07    AS    60       0.0            NaN     2140.0
# 4     2021-03-07    AZ     4  826454.0        56519.0  3073010.0
# ...          ...   ...   ...       ...            ...        ...
# 20775 2020-01-17    WA    53       0.0            NaN        NaN
# 20776 2020-01-16    WA    53       0.0            NaN        NaN
# 20777 2020-01-15    WA    53       0.0            NaN        NaN
# 20778 2020-01-14    WA    53       0.0            NaN        NaN
# 20779 2020-01-13    WA    53       NaN            NaN        NaN
#
#        hospitalizedCumulative  recovered    death  positiveCasesViral  \
# 0                      1293.0        NaN    305.0                 NaN
# ...

# %%
# covid_data20=len(covid_data20[covid_data20['date']>20201231])
# covid_data20=covid_data20.loc[(covid_data20['date']>20201231)]
